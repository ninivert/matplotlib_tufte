# %%
import matplotlib as mpl
import matplotlib.font_manager

# %%
fonts_before = set(mpl.font_manager.fontManager.get_font_names())

# %%
from matplotlib_tufte import *
setup()

# %%
fonts_after = set(mpl.font_manager.fontManager.get_font_names())

# %%
fonts_after - fonts_before
# Out:
# {'Latin Modern Mono',
#  'Latin Modern Mono Caps',
#  'Latin Modern Mono Light',
#  'Latin Modern Mono Light Cond',
#  'Latin Modern Mono Prop',
#  'Latin Modern Mono Prop Light',
#  'Latin Modern Mono Slanted',
#  'Latin Modern Roman',
#  'Latin Modern Roman Caps',
#  'Latin Modern Roman Demi',
#  'Latin Modern Roman Dunhill',
#  'Latin Modern Roman Slanted',
#  'Latin Modern Roman Unslanted',
#  'Latin Modern Sans',
#  'Latin Modern Sans Demi Cond',
#  'Latin Modern Sans Quotation',
#  'NewCMUncial08',
#  'NewCMUncial10',
#  'NewComputerModern08',
#  'NewComputerModern10',
#  'NewComputerModernMath',
#  'NewComputerModernMono10',
#  'NewComputerModernSans08',
#  'NewComputerModernSans10',
#  'NewComputerModernUncial10'}

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

# %% [markdown]
# Basic demo of continuous data

# %%
x = np.linspace(0, 8, 100)
y1 = np.exp(-(x-2)) - np.sin(x-1) + 2
y2 = 5 * 2/(x+0.01) * np.exp(-(np.log(x+0.01)-0.5)**2)
y2[0] = 0

# %%
plt.close('all')
fig, ax = plt.subplots(facecolor='white')
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
ax.plot(x, y1, label='data 1\n$e^{2-x} - \sin(x-1) + 2$')
ax.plot(x, y2, label='data 2')
ax.legend()
plt.show()
fig.savefig('fig1.png')

# %%
plt.close('all')
fig, ax = plt.subplots(facecolor='white')
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
ax.plot(x, y1, label='data 1\n$e^{2-x} - \sin(x-1) + 2$')
ax.plot(x, y2, label='data 2')
ax.legend()
plt.show()
fig.savefig('fig1.png')

# %%
plt.close('all')
fig, ax = plt.subplots(facecolor='white')
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
ax.plot(x, y1, label='data 1')
ax.plot(x, y2, label='data 2')
ax.legend()
breathe(ax)
plt.show()
fig.savefig('fig2.png')

# %%
plt.close('all')
fig, ax = plt.subplots(facecolor='white')
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
ax.plot(x, y1, label='data 1')
ax.plot(x, y2, label='data 2')
ax.legend()
data_lim(ax, 'x')
breathe(ax)
plt.show()
fig.savefig('fig3.png')

# %%
plt.close('all')
fig, ax = plt.subplots(facecolor='white')
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
ax.plot(x, y1, label='data 1')
ax.plot(x, y2, label='data 2')
ax.legend()
data_lim(ax)  # which='both'
breathe(ax)
plt.show()
fig.savefig('fig4.png')

# %% [markdown]
# Getting down and dirty and plotting the distribution of experimental samples, with mean and sample standard deviation

# %%
np.random.seed(0)
N = 50
sample1 = np.random.lognormal(0.9, 0.5, N)
sample2 = np.random.lognormal(0.2, 0.7, N)

means = [np.mean(sample1), np.mean(sample2)]
stds = [np.std(sample1) * np.sqrt(N/(N-1)), np.std(sample2) * np.sqrt(N/(N-1))]  # sample stdev
x = [0, 1]

fig, ax = plt.subplots(figsize=(2, 3), facecolor='white')

for x_, sample, m, s in zip(x, (sample1, sample2), means, stds):
	ax.plot([x_]*len(sample), sample, linestyle='', marker='_', color='k')
	ax.hlines(np.mean(sample), x_-0.3, x_+0.3, linewidth=0.5, color='k')
	ax.add_patch(mpl.patches.FancyArrowPatch(
		arrowstyle='|-|,widthA=2.0,widthB=2.0',
		linewidth=0.5,
		path=mpl.path.Path([(x_-0.3, m-s), (x_-0.3, m+s)]))
	)

ax.set_xticks(x)
ax.set_xticklabels(['S1', 'S2'])

ax.set_xlim((-1, 2))
ax.set_ylim((0, 8))

ax.set_ylabel('measurement')
breathe(ax, 'y')
ax.spines.bottom.set_visible(False)
plt.show()
fig.savefig('fig5.png')
